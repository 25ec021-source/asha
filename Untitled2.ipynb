# %% [markdown]
# <a href="https://colab.research.google.com/github/25ec021-source/asha/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
random_heads_or_tails=random.randint(0,1)
print(random_heads_or_tails)
print("heads")
print("tails")
# Out:
# 0
# heads
# tails

# %%
import random
random_heads_or_tails=random.randint(0,1)
if random_heads_or_tails==0:
  print("heads")
else :
  print("tails")
# Out:
# heads
