# %% [markdown]
# <a href="https://colab.research.google.com/github/25ec021-source/asha/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
user_choice=int(input("what is ur choice,type 0 for rocks,type 1 for papers,type 2 for scissors"))
computer_choice=random.randint(0,2)
print(f"computer chose{computer_choice}")
if user_choice>=3 and user_choice<0:
  print("you typed an invalid number")
elif user_choice==0 and computer_choice ==2:
  print("you win")
elif computer_choice==0 and user_choice==2:
  print("you lose")
elif user_choice>computer_choice:
  print("you win")
elif computer_choice>user_choice:
  print("you lose")
elif computer_choice==user_choice:
  print("match draw")
# Out:
# what is ur choice,type 0 for rocks,type 1 for papers,type 2 for scissors0
# computer chose0
# match draw
